# %% [markdown]
# <a href="https://colab.research.google.com/github/spicy-adobo/LIS-4-5693/blob/main/lab01_text_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
'gensim==4.3.1',
'matplotlib==3.8.4',
'numpy>=1.16',
'nltk==3.9.1',
'pandas>=2.0.3',
'pytesseract==0.3.10',
'regex==2023.6.3',
'requests==2.32.3',
'scikit-learn==1.5.1',
'scipy==1.11.1',
'seaborn==0.12.2',
'spacy==3.5.4',
'vadersentiment==3.3.2'
# Out:
# 'vadersentiment==3.3.2'
