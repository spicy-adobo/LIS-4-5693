# %% [markdown]
# <a href="https://colab.research.google.com/github/spicy-adobo/LIS-4-5693/blob/main/lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
import requests

url = "https://raw.githubusercontent.com/spicy-adobo/LIS-4-5693/refs/heads/main/lab-1/transcript.txt"
response = requests.get(url)
response.raise_for_status() # Raise an exception for HTTP errors
text = response.text

# %%
print("Number of characters:", len(text)) # print number of characters

print(text[:100])   # print first 100 characters
# Out:
# Number of characters: 11004
# hey guys and welcome back
# [Music]
# to my name is Chad chat really and there
# is a new show on A&E the

# %%
nlp = spacy.blank("en")
nlp.add_pipe("sentencizer")

doc = nlp(text)

sentences = list(doc.sents)

print("Number of sentences:", len(sentences))

print("\nFirst 3 sentences:")
for sent in sentences[:3]:
    print(sent)
# Out:
# Number of sentences: 1
#
# First 3 sentences:
# hey guys and welcome back
# [Music]
# to my name is Chad chat really and there
# is a new show on A&E the same network
# that brought us such bangers As Dog the
# Bounty Hunter Storage Wars and Billy the
# Exterminator I've got to take every
# shortcut I
# can adults adopting adults is the new
# hot Goss online it's the new thing but I
# wasn't sure I wanted to make a video on
# this because I've seen that people have
# already talked about it but then I
# watched the first episode in a moment of
# weakness and it was way way worse than I
# thought I'm already not a huge fan of
# reality TV because it's usually not
# reality king just cheated on me oh my
# god seriously I am going to
# end his career oh in living as a
# successful businessman okay yeah okay if
# his business was breathing no there's
# actually a lot of reasons for adult
# adoption like foster kids wanting to be
# adopted by their foster parents or step
# ...

# %% [markdown]
# Unfortunately my transcript from the previous lab is mistakenly only one sentence

# %%
words = [token.text.lower() for token in doc if token.is_alpha]

print("Total words:", len(words))
print("Unique words:", len(set(words)))
# Out:
# Total words: 2145
# Unique words: 617

# %%
from collections import Counter

word_freq = Counter(words)

print("most frequent word:")
for word, count in word_freq.most_common(1):
    print(word, count)
# Out:
# most frequent word:
# i 78

# %% [markdown]
# I assume the reason for the most frequent word being I, is due to the fact this is a youtuber's commentary on distasteful videos and in order to share their opinion have to say "I" often.

# %%
nlp2 = spacy.load("en_core_web_sm")

doc2 = nlp2(text)

print("Named Entities:")
for ent in doc2.ents:
    print(ent.text, ent.label_)
# Out:
# Named Entities:
# Chad PERSON
# A&E ORG
# Billy PERSON
# Goss PERSON
# first ORDINAL
# one CARDINAL
# Danny PERSON
# Christie Danny PERSON
# Christie ORG
# Danny PERSON
# Christy PERSON
# Ohio GPE
# Christy PERSON
# Danny PERSON
# three months DATE
# more than one CARDINAL
# Danny PERSON
# 18-year-old DATE
# years DATE
# first ORDINAL
# first ORDINAL
# first ORDINAL
# Danny PERSON
# creepy NORP
# Danny PERSON
# one CARDINAL
# Danny PERSON
# 8,000 MONEY
# Danny PERSON
# Elana PERSON
# Italian NORP
# Ohio GPE
# blowy PERSON
# Danny PERSON
# Christy PERSON
# Elana ORG
# Danny PERSON
# Iana GPE
# Danny PERSON
# Kevin Malone PERSON
# Ilana ORG
# the Declaration of Independence WORK_OF_ART
# the Declaration of Independence WORK_OF_ART
# Sofer PRODUCT
# Elana ORG
# Danny PERSON
# Eliana GPE
# Christy PERSON
# Christy PERSON
# Facebook 5 years ago DATE
# the day DATE
# creepy NORP
# 2 seconds TIME
# Aliana PERSON
# Christy PERSON
# three CARDINAL
# Elana PERSON
# yesterday DATE
# Elana ORG
# ...

# %%
from spacy.matcher import PhraseMatcher

matcher = PhraseMatcher(nlp2.vocab, attr="LOWER")

phrases = ["relationship", "adopting adults", "family"]

patterns = [nlp2(p) for p in phrases]

matcher.add("TECH_TERMS", patterns)

matches = matcher(doc2)

print("Matches found:")
for match_id, start, end in matches:
    print(doc2[start:end])
    print("Sentence:", doc2[start].sent)
# Out:
# Matches found:
# adopting adults
# Sentence: [Music]
# to my name is Chad chat really and there
# is a new show on A&E the same network
# that brought us such bangers As Dog the
# Bounty Hunter Storage Wars and Billy the
# Exterminator I've got to take every
# shortcut I
# can adults adopting adults is the new
# hot Goss
# family
# Sentence: if
# his business was breathing no there's
# actually a lot of reasons for adult
# adoption like foster kids wanting to be
# adopted by their foster parents or step
# kids who have become adults who want to
# be adopted by their step parents so
# adult adoption isn't inherently strange
# but this is reality TV guys they can't
# make a show about healthy
# relationships get that out of here so
# the show starts out introducing us to
# the different couples who are looking to
# adopt an adult and immediately one
# couple sticks out to us Danny and
# Christie Danny and Christie have this
# really interesting dynamic where Danny
# ...

# %% [markdown]
# I think in the craziness of my personal life, I completely missed the brief of what topic to pick. When initially doing Lab 1 due to mistakenly copying an extra character in the link I kept getting errors. So in that stress, I was just trying videos I had recently watched. Apologies. I'll download a new transcript and rerun the assignment.

# %% [markdown]
# # Attempt 2

# %% [markdown]
# ## Task 1: Loading Transcript

# %%
import requests

url = "https://raw.githubusercontent.com/spicy-adobo/LIS-4-5693/refs/heads/main/lab-1/newtranscript.txt"
response = requests.get(url)
response.raise_for_status() # Raise an exception for HTTP errors
text = response.text

# %% [markdown]
# ##Task 2: Printing and counting characters

# %%
print("Number of characters:", len(text)) # print number of characters

print(text[:100])   # print first 100 characters
# Out:
# Number of characters: 3846
# Here are five things to know about neural
# networks in under five minutes. Number one:
# neural netw

# %% [markdown]
# ## Task 3: Sentence Segmentation

# %%
nlp = spacy.blank("en")
nlp.add_pipe("sentencizer")

doc = nlp(text)

sentences = list(doc.sents)

print("Number of sentences:", len(sentences))

print("\nFirst 3 sentences:")
for sent in sentences[:3]:
    print(sent)
# Out:
# Number of sentences: 41
#
# First 3 sentences:
# Here are five things to know about neural
# networks in under five minutes.
# Number one:
# neural networks are composed of node layers.
# There
# is an input node layer, there is a hidden layer,
# and there is an output layer.

# %% [markdown]
# ## Task 4: Word Count and Token Analysis

# %%
words = [token.text.lower() for token in doc if token.is_alpha]

print("Total words:", len(words))
print("Unique words:", len(set(words)))
# Out:
# Total words: 638
# Unique words: 258

# %% [markdown]
# ## Task 5: Finding the Most Frequent Words

# %%
from collections import Counter

word_freq = Counter(words)

print("most frequent word:")
for word, count in word_freq.most_common(1):
    print(word, count)
# Out:
# most frequent word:
# the 32

# %% [markdown]
# The most frequent word is the, which as a definite article makes sense especially in a video explaining how a topic works.

# %% [markdown]
# ## Task 6: Full spaCy pipeline

# %%
nlp2 = spacy.load("en_core_web_sm")

doc2 = nlp2(text)

print("Named Entities:")
for ent in doc2.ents:
    print(ent.text, ent.label_)
# Out:
# Named Entities:
# five CARDINAL
# under five minutes TIME
# one CARDINAL
# node GPE
# AI GPE
# two CARDINAL
# Linear ORG
# node GPE
# one CARDINAL
# three CARDINAL
# three CARDINAL
# 1 CARDINAL
# 1 CARDINAL
# 1 CARDINAL
# x3 PERSON
# 0 CARDINAL
# 5 CARDINAL
# 5 CARDINAL
# 2 CARDINAL
# 1 CARDINAL
# 5 CARDINAL
# 0 CARDINAL
# 2 CARDINAL
# 1 CARDINAL
# 4 CARDINAL
# 6. CARDINAL
# Six CARDINAL
# 1 CARDINAL
# four CARDINAL
# four CARDINAL
# five CARDINAL
# five CARDINAL
# five minutes TIME
# Subscribe PRODUCT

# %% [markdown]
# The types are mostly CARDINAL, TIME, and GPE, but also includes a PRODUCT.

# %% [markdown]
# ## Task 7: PhraseMatcher

# %%
from spacy.matcher import PhraseMatcher

matcher = PhraseMatcher(nlp2.vocab, attr="LOWER")

phrases = ["data science", "neural networks", "node"]

patterns = [nlp2(p) for p in phrases]

matcher.add("TECH_TERMS", patterns)

matches = matcher(doc2)

print("Matches found:")
for match_id, start, end in matches:
    print(doc2[start:end])
    print("Sentence:", doc2[start].sent)
# Out:
# Matches found:
# neural networks
# Sentence: Number one:
# neural networks are composed of node layers.
# node
# Sentence: Number one:
# neural networks are composed of node layers.
# node
# Sentence: There
# is an input node layer, there is a hidden layer,
# and there is an output layer.
# node
# Sentence: Now,
# think of each node, or artificial neuron, as its own
# linear regression model.
# node
# Sentence: So each
# node is composed of input data, weights, a bias,
# or a threshold, and then an output.
# node
# Sentence: To illustrate this, let's consider
# what a single node in our neural network might
# look like to decide -- should we go surfing.
# node
# Sentence: Six is greater than 0, so the
# output of this node is 1 --
# neural networks
# Sentence: Well, yes, but but but number four, neural networks
# rely on training data to learn and improve their
# accuracy over time.
# neural networks
# Sentence: For example, there are
# ...

# %% [markdown]
# ##Task 8:
#
#
# Overall the whole lab went very well. I did have an issue with the raw link in the Lab 2 assignment so I just used the link from the introduction to spaCy assignment. Also, having not done the first assignment completely properly having to redo it was a little challenging but I will take any practice I can get.
